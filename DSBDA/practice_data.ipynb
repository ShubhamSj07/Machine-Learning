# %% [markdown]
# **Assignment No.1 (DS&BDA Lab)**

# %% [markdown]
# **Name : Pradnya Salve**

# %% [markdown]
# **Roll No : TEITA51009**

# %% [markdown]
# **PRN No : 72018486L**

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\icon\\Desktop\\ML_TE\\dataset\\dataset_Facebook.csv",delimiter=';')

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.tail()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
df.shape
# Out:
# (500, 19)

# %% [markdown]
# **1. Creating subsets with 5 columns and 50 rows**

# %%
s1 = df.loc[0:49,['Type','Post Weekday','Post Hour','like','share']] 
s1
# Out:
#       Type  Post Weekday  Post Hour    like  share
# 0    Photo             4          3    79.0   17.0
# 1   Status             3         10   130.0   29.0
# 2    Photo             3          3    66.0   14.0
# 3    Photo             2         10  1572.0  147.0
# 4    Photo             2          3   325.0   49.0
# 5   Status             1          9   152.0   33.0
# 6    Photo             1          3   249.0   27.0
# 7    Photo             7          9   325.0   14.0
# 8   Status             7          3   161.0   31.0
# 9    Photo             6         10   113.0   26.0
# 10  Status             5         10   233.0   19.0
# 11   Photo             5         10    88.0   18.0
# 12   Photo             5         10    90.0   14.0
# 13   Photo             5          3   137.0   10.0
# 14   Photo             4          5   577.0   20.0
# 15  Status             3         10    86.0   18.0
# 16   Photo             3          3    40.0   12.0
# ...

# %% [markdown]
# **2. Creating subsets with 4 columns and 25 rows**

# %%
s2 =  df.loc[0:24,['Type','Total Interactions','like','share']]   
s2
# Out:
#       Type  Total Interactions    like  share
# 0    Photo                 100    79.0   17.0
# 1   Status                 164   130.0   29.0
# 2    Photo                  80    66.0   14.0
# 3    Photo                1777  1572.0  147.0
# 4    Photo                 393   325.0   49.0
# 5   Status                 186   152.0   33.0
# 6    Photo                 279   249.0   27.0
# 7    Photo                 339   325.0   14.0
# 8   Status                 192   161.0   31.0
# 9    Photo                 142   113.0   26.0
# 10  Status                 252   233.0   19.0
# 11   Photo                 106    88.0   18.0
# 12   Photo                 104    90.0   14.0
# 13   Photo                 152   137.0   10.0
# 14   Photo                 599   577.0   20.0
# 15  Status                 108    86.0   18.0
# 16   Photo                  54    40.0   12.0
# 17   Photo                 713   678.0   20.0
# 18  Status                  75    54.0   17.0
# ...

# %% [markdown]
# **3.Creating subsets having Post Hour >3**

# %%
s3 =  df[df['Post Hour']>3]
s3
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 3              139441   Photo         2          12             2         10
# 5              139441  Status         2          12             1          9
# 7              139441   Photo         3          12             7          9
# 9              139441   Photo         3          12             6         10
# ..                ...     ...       ...         ...           ...        ...
# 492             85979    Link         1           1             5         11
# 494             85093   Photo         3           1             7         10
# 496             81370   Photo         2           1             5          8
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %% [markdown]
# **4. Sort subset 1 on like and share in descending order**

# %%
result_sort = s1.sort_values(by='like',ascending = False)
result_sort
# Out:
#       Type  Post Weekday  Post Hour    like  share
# 3    Photo             2         10  1572.0  147.0
# 17   Photo             2         12   678.0   20.0
# 14   Photo             4          5   577.0   20.0
# 28   Photo             5          3   523.0   63.0
# 26  Status             5         11   412.0   72.0
# 4    Photo             2          3   325.0   49.0
# 7    Photo             7          9   325.0   14.0
# 6    Photo             1          3   249.0   27.0
# 10  Status             5         10   233.0   19.0
# 38  Status             7          9   227.0   31.0
# 40  Status             6         11   216.0   39.0
# 41    Link             6          3   187.0   18.0
# 46  Status             3         11   174.0   36.0
# 35   Photo             1         11   172.0   21.0
# 8   Status             7          3   161.0   31.0
# 32   Photo             3          3   155.0   47.0
# 5   Status             1          9   152.0   33.0
# ...

# %%
result_sort = s1.sort_values(by='share',ascending = False)
result_sort
# Out:
#       Type  Post Weekday  Post Hour    like  share
# 3    Photo             2         10  1572.0  147.0
# 26  Status             5         11   412.0   72.0
# 28   Photo             5          3   523.0   63.0
# 4    Photo             2          3   325.0   49.0
# 32   Photo             3          3   155.0   47.0
# 40  Status             6         11   216.0   39.0
# 46  Status             3         11   174.0   36.0
# 5   Status             1          9   152.0   33.0
# 38  Status             7          9   227.0   31.0
# 8   Status             7          3   161.0   31.0
# 1   Status             3         10   130.0   29.0
# 6    Photo             1          3   249.0   27.0
# 9    Photo             6         10   113.0   26.0
# 23   Photo             7          3    72.0   24.0
# 33   Photo             2          9    98.0   23.0
# 30   Photo             4          2   107.0   22.0
# 35   Photo             1         11   172.0   21.0
# ...

# %% [markdown]
# **5. Merge first two subset on Type and sort them on no of shares(share column)**

# %%
newdf = pd.merge(s1, s2, on='Type')
newdf
# Out:
#       Type  Post Weekday  Post Hour  like_x  share_x  Total Interactions  \
# 0    Photo             4          3    79.0     17.0                 100
# 1    Photo             4          3    79.0     17.0                  80
# 2    Photo             4          3    79.0     17.0                1777
# 3    Photo             4          3    79.0     17.0                 393
# 4    Photo             4          3    79.0     17.0                 279
# ..     ...           ...        ...     ...      ...                 ...
# 612   Link             6          3   187.0     18.0                  18
# 613   Link             5          3    29.0     10.0                  18
# 614   Link             4          3    57.0     10.0                  18
# 615   Link             3          2    18.0      8.0                  18
# 616   Link             2          2    12.0      1.0                  18
#
#      like_y  share_y
# 0      79.0     17.0
# 1      66.0     14.0
# 2    1572.0    147.0
# ...

# %%
result = newdf.sort_values(by=['share_x','share_y'])
result
# Out:
#       Type  Post Weekday  Post Hour  like_x  share_x  Total Interactions  \
# 270  Photo             7         10     0.0      0.0                   0
# 268  Photo             7         10     0.0      0.0                  42
# 264  Photo             7         10     0.0      0.0                 152
# 266  Photo             7         10     0.0      0.0                  54
# 269  Photo             7         10     0.0      0.0                  81
# ..     ...           ...        ...     ...      ...                 ...
# 50   Photo             2         10  1572.0    147.0                  96
# 40   Photo             2         10  1572.0    147.0                 142
# 38   Photo             2         10  1572.0    147.0                 279
# 37   Photo             2         10  1572.0    147.0                 393
# 36   Photo             2         10  1572.0    147.0                1777
#
#      like_y  share_y
# 270     0.0      0.0
# 268    34.0      8.0
# 264   137.0     10.0
# ...

# %% [markdown]
# **6. Merge first two subsets on different left(like) and right columns(share)**

# %%
mg1 = s1.merge(s2,left_on = 'like',right_on = 'share')
mg1
# Out:
#   Type_x  Post Weekday  Post Hour  like_x  share_x  Type_y  \
# 0  Photo             7         10     0.0      0.0   Photo
# 1  Photo             3         10    27.0     11.0   Photo
# 2  Photo             5         10    26.0      3.0   Photo
# 3   Link             5          3    29.0     10.0  Status
# 4   Link             3          2    18.0      8.0   Photo
# 5   Link             3          2    18.0      8.0  Status
# 6   Link             2          2    12.0      1.0   Photo
# 7   Link             2          2    12.0      1.0   Photo
#
#    Total Interactions  like_y  share_y
# 0                   0     0.0      0.0
# 1                 279   249.0     27.0
# 2                 142   113.0     26.0
# 3                 164   130.0     29.0
# 4                 106    88.0     18.0
# 5                 108    86.0     18.0
# 6                  54    40.0     12.0
# 7                  81    66.0     12.0

# %% [markdown]
# **7. Transpose first two subsets and sort them in descending order**

# %%
tran_result1 = s1.transpose()
tran_result1
# Out:
#                  0       1      2       3      4       5      6      7   \
# Type          Photo  Status  Photo   Photo  Photo  Status  Photo  Photo
# Post Weekday      4       3      3       2      2       1      1      7
# Post Hour         3      10      3      10      3       9      3      9
# like           79.0   130.0   66.0  1572.0  325.0   152.0  249.0  325.0
# share          17.0    29.0   14.0   147.0   49.0    33.0   27.0   14.0
#
#                   8      9   ...      40     41     42    43     44    45  \
# Type          Status  Photo  ...  Status   Link  Photo  Link  Photo  Link
# Post Weekday       7      6  ...       6      6      5     5      4     4
# Post Hour          3     10  ...      11      3     10     3     11     3
# like           161.0  113.0  ...   216.0  187.0   26.0  29.0   47.0  57.0
# share           31.0   26.0  ...    39.0   18.0    3.0  10.0   11.0  10.0
#
#                   46    47     48    49
# Type          Status  Link  Photo  Link
# ...

# %%
tran_result2 = s2.transpose()
tran_result2
# Out:
#                        0       1      2       3      4       5      6      7   \
# Type                Photo  Status  Photo   Photo  Photo  Status  Photo  Photo
# Total Interactions    100     164     80    1777    393     186    279    339
# like                 79.0   130.0   66.0  1572.0  325.0   152.0  249.0  325.0
# share                17.0    29.0   14.0   147.0   49.0    33.0   27.0   14.0
#
#                         8      9   ...      15     16     17      18     19  \
# Type                Status  Photo  ...  Status  Photo  Photo  Status  Photo
# Total Interactions     192    142  ...     108     54    713      75     42
# like                 161.0  113.0  ...    86.0   40.0  678.0    54.0   34.0
# share                 31.0   26.0  ...    18.0   12.0   20.0    17.0    8.0
#
#                        20     21    22     23      24
# Type                Photo  Photo  Link  Photo  Status
# Total Interactions     81      0    18     96     121
# ...

# %%
sort_result = tran_result1.sort_values(by = 'like',axis=1,ascending = False)
sort_result
# Out:
#                   3      17     14     28      26     4      7      6   \
# Type           Photo  Photo  Photo  Photo  Status  Photo  Photo  Photo
# Post Weekday       2      2      4      5       5      2      7      1
# Post Hour         10     12      5      3      11      3      9      3
# like          1572.0  678.0  577.0  523.0   412.0  325.0  325.0  249.0
# share          147.0   20.0   20.0   63.0    72.0   49.0   14.0   27.0
#
#                   10      38  ...     39     16     19    43     31     42  \
# Type          Status  Status  ...  Photo  Photo  Photo  Link  Photo  Photo
# Post Weekday       5       7  ...      7      3      1     5      3      5
# Post Hour         10       9  ...      3      3     11     3     10     10
# like           233.0   227.0  ...   44.0   40.0   34.0  29.0   27.0   26.0
# share           19.0    31.0  ...   14.0   12.0    8.0  10.0   11.0    3.0
#
#                 47    22    49     21
# Type          Link  Link  Link  Photo
# ...

# %% [markdown]
# **8. Show all dataframes in wide and long formats. Convert wide to long and vice versa**

# %%
rslt = s1.melt()
rslt
# Out:
#     variable   value
# 0       Type   Photo
# 1       Type  Status
# 2       Type   Photo
# 3       Type   Photo
# 4       Type   Photo
# ..       ...     ...
# 245    share    10.0
# 246    share    36.0
# 247    share     8.0
# 248    share    15.0
# 249    share     1.0
#
# [250 rows x 2 columns]

# %%
rslt1= s1.pivot(columns = 'Post Hour', values = 'Post Weekday')
rslt1
# Out:
# Post Hour   2    3    5    9    10   11   12
# 0          NaN  4.0  NaN  NaN  NaN  NaN  NaN
# 1          NaN  NaN  NaN  NaN  3.0  NaN  NaN
# 2          NaN  3.0  NaN  NaN  NaN  NaN  NaN
# 3          NaN  NaN  NaN  NaN  2.0  NaN  NaN
# 4          NaN  2.0  NaN  NaN  NaN  NaN  NaN
# 5          NaN  NaN  NaN  1.0  NaN  NaN  NaN
# 6          NaN  1.0  NaN  NaN  NaN  NaN  NaN
# 7          NaN  NaN  NaN  7.0  NaN  NaN  NaN
# 8          NaN  7.0  NaN  NaN  NaN  NaN  NaN
# 9          NaN  NaN  NaN  NaN  6.0  NaN  NaN
# 10         NaN  NaN  NaN  NaN  5.0  NaN  NaN
# 11         NaN  NaN  NaN  NaN  5.0  NaN  NaN
# 12         NaN  NaN  NaN  NaN  5.0  NaN  NaN
# 13         NaN  5.0  NaN  NaN  NaN  NaN  NaN
# 14         NaN  NaN  4.0  NaN  NaN  NaN  NaN
# 15         NaN  NaN  NaN  NaN  3.0  NaN  NaN
# 16         NaN  3.0  NaN  NaN  NaN  NaN  NaN
# 17         NaN  NaN  NaN  NaN  NaN  NaN  2.0
# 18         NaN  2.0  NaN  NaN  NaN  NaN  NaN
# 19         NaN  NaN  NaN  NaN  NaN  1.0  NaN
# ...

# %%
rslt2 = s2.melt()
rslt2
# Out:
#    variable   value
# 0      Type   Photo
# 1      Type  Status
# 2      Type   Photo
# 3      Type   Photo
# 4      Type   Photo
# ..      ...     ...
# 95    share    12.0
# 96    share     0.0
# 97    share     2.0
# 98    share    24.0
# 99    share    19.0
#
# [100 rows x 2 columns]

# %%
rslt3 = s2.pivot(columns = 'Type', values = 'like')
rslt3
# Out:
# Type  Link   Photo  Status
# 0      NaN    79.0     NaN
# 1      NaN     NaN   130.0
# 2      NaN    66.0     NaN
# 3      NaN  1572.0     NaN
# 4      NaN   325.0     NaN
# 5      NaN     NaN   152.0
# 6      NaN   249.0     NaN
# 7      NaN   325.0     NaN
# 8      NaN     NaN   161.0
# 9      NaN   113.0     NaN
# 10     NaN     NaN   233.0
# 11     NaN    88.0     NaN
# 12     NaN    90.0     NaN
# 13     NaN   137.0     NaN
# 14     NaN   577.0     NaN
# 15     NaN     NaN    86.0
# 16     NaN    40.0     NaN
# 17     NaN   678.0     NaN
# 18     NaN     NaN    54.0
# 19     NaN    34.0     NaN
# 20     NaN    66.0     NaN
# 21     NaN     0.0     NaN
# 22    16.0     NaN     NaN
# 23     NaN    72.0     NaN
# 24     NaN     NaN    99.0
