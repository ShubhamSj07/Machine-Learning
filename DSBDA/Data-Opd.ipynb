# %%
import pandas as pd

# %%
data = pd.read_csv("./fb.csv")

# %%
data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
data.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
data.tail()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
data.shape
# Out:
# (500, 19)

# %%
set1 = data.loc[0:49, ['Type','Category', 'Post Month', 'like', 'share']]

# %%
set2 = data.loc[0:24, ['Type', 'comment', 'Total Interactions', 'like', 'share']]

# %%
mergeData = pd.merge(set1, set2)

# %%
mergeData
# Out:
#       Type  Category  Post Month    like  share  comment  Total Interactions
# 0    Photo         2          12    79.0   17.0        4                 100
# 1   Status         2          12   130.0   29.0        5                 164
# 2    Photo         3          12    66.0   14.0        0                  80
# 3    Photo         2          12  1572.0  147.0       58                1777
# 4    Photo         2          12   325.0   49.0       19                 393
# 5   Status         2          12   152.0   33.0        1                 186
# 6    Photo         3          12   249.0   27.0        3                 279
# 7    Photo         3          12   325.0   14.0        0                 339
# 8   Status         2          12   161.0   31.0        0                 192
# 9    Photo         3          12   113.0   26.0        3                 142
# 10  Status         2          12   233.0   19.0        0                 252
# ...

# %%
set3 = data[data['Post Hour'] > 3]

# %%
set3
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 3              139441   Photo         2          12             2         10
# 5              139441  Status         2          12             1          9
# 7              139441   Photo         3          12             7          9
# 9              139441   Photo         3          12             6         10
# ..                ...     ...       ...         ...           ...        ...
# 492             85979    Link         1           1             5         11
# 494             85093   Photo         3           1             7         10
# 496             81370   Photo         2           1             5          8
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
set1.sort_values(by=['like', 'share'], ascending=False)
# Out:
#       Type  Category  Post Month    like  share
# 3    Photo         2          12  1572.0  147.0
# 17   Photo         1          12   678.0   20.0
# 14   Photo         2          12   577.0   20.0
# 28   Photo         2          12   523.0   63.0
# 26  Status         2          12   412.0   72.0
# 4    Photo         2          12   325.0   49.0
# 7    Photo         3          12   325.0   14.0
# 6    Photo         3          12   249.0   27.0
# 10  Status         2          12   233.0   19.0
# 38  Status         2          12   227.0   31.0
# 40  Status         2          12   216.0   39.0
# 41    Link         1          12   187.0   18.0
# 46  Status         1          12   174.0   36.0
# 35   Photo         2          12   172.0   21.0
# 8   Status         2          12   161.0   31.0
# 32   Photo         3          12   155.0   47.0
# 5   Status         2          12   152.0   33.0
# 29   Video         1          12   143.0   13.0
# 13   Photo         2          12   137.0   10.0
# ...

# %%
result = pd.merge(set1, set2, on='Type')

# %%
result
# Out:
#       Type  Category  Post Month  like_x  share_x  comment  \
# 0    Photo         2          12    79.0     17.0        4
# 1    Photo         2          12    79.0     17.0        0
# 2    Photo         2          12    79.0     17.0       58
# 3    Photo         2          12    79.0     17.0       19
# 4    Photo         2          12    79.0     17.0        3
# ..     ...       ...         ...     ...      ...      ...
# 612   Link         1          12   187.0     18.0        0
# 613   Link         1          12    29.0     10.0        0
# 614   Link         1          12    57.0     10.0        0
# 615   Link         1          12    18.0      8.0        0
# 616   Link         1          12    12.0      1.0        0
#
#      Total Interactions  like_y  share_y
# 0                   100    79.0     17.0
# 1                    80    66.0     14.0
# 2                  1777  1572.0    147.0
# 3                   393   325.0     49.0
# 4                   279   249.0     27.0
# ...

# %%
result.sort_values(by="share_x")
# Out:
#       Type  Category  Post Month  like_x  share_x  comment  \
# 270  Photo         1          12     0.0      0.0        0
# 268  Photo         1          12     0.0      0.0        0
# 267  Photo         1          12     0.0      0.0       15
# 266  Photo         1          12     0.0      0.0        2
# 265  Photo         1          12     0.0      0.0        2
# ..     ...       ...         ...     ...      ...      ...
# 48   Photo         2          12  1572.0    147.0        3
# 49   Photo         2          12  1572.0    147.0        0
# 50   Photo         2          12  1572.0    147.0        0
# 43   Photo         2          12  1572.0    147.0        5
# 35   Photo         2          12  1572.0    147.0        0
#
#      Total Interactions  like_y  share_y
# 270                   0     0.0      0.0
# 268                  42    34.0      8.0
# 267                 713   678.0     20.0
# 266                  54    40.0     12.0
# 265                 599   577.0     20.0
# ...

# %%
t1 = set1.transpose()

# %%
t1
# Out:
#                0       1      2      3      4       5      6      7       8   \
# Type        Photo  Status  Photo  Photo  Photo  Status  Photo  Photo  Status
# Category        2       2      3      2      2       2      3      3       2
# Post Month     12      12     12     12     12      12     12     12      12
# like           79     130     66   1572    325     152    249    325     161
# share          17      29     14    147     49      33     27     14      31
#
#                9   ...      40    41     42    43     44    45      46    47  \
# Type        Photo  ...  Status  Link  Photo  Link  Photo  Link  Status  Link
# Category        3  ...       2     1      1     1      1     1       1     1
# Post Month     12  ...      12    12     12    12     12    12      12    12
# like          113  ...     216   187     26    29     47    57     174    18
# share          26  ...      39    18      3    10     11    10      36     8
#
#                48    49
# ...

# %%
t2 = set2.transpose()
t2
# Out:
#                        0       1      2      3      4       5      6      7   \
# Type                Photo  Status  Photo  Photo  Photo  Status  Photo  Photo
# comment                 4       5      0     58     19       1      3      0
# Total Interactions    100     164     80   1777    393     186    279    339
# like                   79     130     66   1572    325     152    249    325
# share                  17      29     14    147     49      33     27     14
#
#                         8      9   ...      15     16     17      18     19  \
# Type                Status  Photo  ...  Status  Photo  Photo  Status  Photo
# comment                  0      3  ...       4      2     15       4      0
# Total Interactions     192    142  ...     108     54    713      75     42
# like                   161    113  ...      86     40    678      54     34
# share                   31     26  ...      18     12     20      17      8
#
# ...

# %%
t2.sort_values(by=["like"], ascending=False, axis=1)
# Out:
#                        3      17     14     4      7      6       10      8   \
# Type                Photo  Photo  Photo  Photo  Photo  Photo  Status  Status
# comment                58     15      2     19      0      3       0       0
# Total Interactions   1777    713    599    393    339    279     252     192
# like                 1572    678    577    325    325    249     233     161
# share                 147     20     20     49     14     27      19      31
#
#                         5      13  ...      15     0      23     2      20  \
# Type                Status  Photo  ...  Status  Photo  Photo  Photo  Photo
# comment                  1      5  ...       4      4      0      0      3
# Total Interactions     186    152  ...     108    100     96     80     81
# like                   152    137  ...      86     79     72     66     66
# share                   33     10  ...      18     17     24     14     12
#
# ...
